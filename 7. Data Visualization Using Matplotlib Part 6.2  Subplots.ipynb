# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('iris_code.csv')

# %%
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# # draw each plot side by side  inplce histo we can use any other graph

# %%
plt.subplot(1,2,1)
# one row 2 clmn index 1
plt.subplot(1,2,2)
# one row 2 clmn index 2
# Out:
# <AxesSubplot: >

# %%
data.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
plt.subplot(1,2,1)
plt.hist(data.SepalLengthCm)

plt.subplot(1,2,2)
plt.hist(data.PetalLengthCm)
plt.show()
# 2graph crated

# %%
# give super title
plt.suptitle('Iris Dataset')
plt.subplot(1,2,1)
plt.hist(data.SepalLengthCm)

plt.subplot(1,2,2)
plt.hist(data.PetalLengthCm)
plt.show()

# %%
# title for garph

# give super title
plt.suptitle('Iris Dataset')
plt.subplot(1,2,1)
plt.hist(data.SepalLengthCm)
plt.title('SepalLengthCm')

plt.subplot(1,2,2)
plt.hist(data.PetalLengthCm)
plt.title('PetalLengthCm')

plt.show()

# %%
# change colour
plt.suptitle('Iris Dataset')
plt.subplot(1,2,1)
plt.hist(data.SepalLengthCm,color='g')
plt.title('SepalLengthCm')

plt.subplot(1,2,2)
plt.hist(data.PetalLengthCm,color='k')
plt.title('PetalLengthCm')

plt.show()

# %%
# x and y label

# change colour
plt.suptitle('Iris Dataset')
plt.subplot(1,2,1)
plt.hist(data.SepalLengthCm,color='g')
plt.title('SepalLengthCm')
plt.xlabel('SepalLengthCm')
plt.ylabel('Counts')

plt.subplot(1,2,2)
plt.hist(data.PetalLengthCm,color='k')
plt.title('PetalLengthCm')
plt.xlabel('PetalLengthCm')
plt.ylabel('Counts')

plt.show()

# %%
# remove over lapping of graph
plt.suptitle('Iris Dataset')
plt.subplot(1,2,1)
plt.hist(data.SepalLengthCm,color='g')
plt.title('SepalLengthCm')
plt.xlabel('SepalLengthCm')
plt.ylabel('Counts')

plt.subplot(1,2,2)
plt.hist(data.PetalLengthCm,color='k')
plt.title('PetalLengthCm')
plt.xlabel('PetalLengthCm')
plt.ylabel('Counts')

plt.tight_layout()  # remove over lapping of graph
plt.show()

# %% [markdown]
# # 2 plot top of each other

# %%
# remove over lapping of graph
plt.suptitle('Iris Dataset')
plt.subplot(2,1,1)
plt.hist(data.SepalLengthCm,color='g')
plt.title('SepalLengthCm')
plt.xlabel('SepalLengthCm')
plt.ylabel('Counts')

plt.subplot(2,1,2)
plt.hist(data.PetalLengthCm,color='k')
plt.title('PetalLengthCm')
plt.xlabel('PetalLengthCm')
plt.ylabel('Counts')

plt.tight_layout()  # remove over lapping of graph
plt.show()

# %% [markdown]
# # 4 plot draws

# %%
# remove over lapping of graph
plt.suptitle('Iris Dataset')
plt.subplot(2,2,1)
plt.hist(data.SepalLengthCm,color='g')
plt.title('SepalLengthCm')
plt.xlabel('SepalLengthCm')
plt.ylabel('Counts')

plt.subplot(2,2,2)
plt.hist(data.PetalLengthCm,color='k')
plt.title('PetalLengthCm')
plt.xlabel('PetalLengthCm')
plt.ylabel('Counts')

plt.suptitle('Iris Dataset')
plt.subplot(2,2,3)
plt.hist(data.SepalWidthCm,color='y')
plt.title('SepalWidthCm')
plt.xlabel('SepalWidthCm')
plt.ylabel('Counts')

plt.subplot(2,2,4)
plt.hist(data.PetalWidthCm,color='b')
plt.title('PetalWidthCm')
plt.xlabel('PetalWidthCm')
plt.ylabel('Counts')

plt.tight_layout()  # remove over lapping of graph
plt.show()

# %%
data.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %% [markdown]
# # fig size fig colour

# %%
plt.figure(figsize=(10,10),facecolor='green',edgecolor='black',linewidth=5)  # its no showing bcs by default line width is 0 so change


# remove over lapping of graph
plt.suptitle('Iris Dataset')
plt.subplot(2,2,1)
plt.hist(data.SepalLengthCm,color='g')
plt.title('SepalLengthCm')
plt.xlabel('SepalLengthCm')
plt.ylabel('Counts')

plt.subplot(2,2,2)
plt.hist(data.PetalLengthCm,color='k')
plt.title('PetalLengthCm')
plt.xlabel('PetalLengthCm')
plt.ylabel('Counts')

plt.suptitle('Iris Dataset')
plt.subplot(2,2,3)
plt.hist(data.SepalWidthCm,color='y')
plt.title('SepalWidthCm')
plt.xlabel('SepalWidthCm')
plt.ylabel('Counts')

plt.subplot(2,2,4)
plt.hist(data.PetalWidthCm,color='b')
plt.title('PetalWidthCm')
plt.xlabel('PetalWidthCm')
plt.ylabel('Counts')

plt.tight_layout()  # remove over lapping of graph
plt.show()

# %% [markdown]
# # Subplots Method

# %% [markdown]
# # 2 graph side by side

# %%
data.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
plt.subplots(nrows=1,ncols=2)
# Out:
# (<Figure size 640x480 with 2 Axes>,
#  array([<AxesSubplot: >, <AxesSubplot: >], dtype=object))

# %%
# (<Figure size 640x480 with 2 Axes>,# array([<AxesSubplot: >, <AxesSubplot: >], dtype=object))
# we have to use abv figure level objects

# %%
fig,(ax1,ax2)= plt.subplots(nrows=1,ncols=2)
# ax1 axis subplot 1
# ax2 axis subplot 2

# %%
# plot sepel length and petal length
fig,(ax1,ax2)= plt.subplots(nrows=1,ncols=2)
ax1.hist(data.SepalLengthCm,color='g')
plt.show()

# %%
# here we are accessing figure  axex level object
fig,(ax1,ax2)= plt.subplots(nrows=1,ncols=2) # first wecode  fig lev ax
fig.suptitle('Iris_dataset')

ax1.hist(data.SepalLengthCm,color='g')
ax1.set_title('SepalLengthCm') # for giving titel of one graph
ax1.set_xlabel('SepalLengthCm')
ax1.set_ylabel('Counts')

ax2.hist(data.PetalLengthCm,color='k')
ax2.set_title('PetalLengthCm') # for giving titel of one graph
ax2.set_xlabel('PetalLengthCm')
ax2.set_ylabel('Counts')

plt.tight_layout() # -- remove overlapping of graph or count label
plt.show()

# %% [markdown]
# # draw plot to p of each other

# %%
data.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
# here we are accessing figure  axex level object
fig,(ax1,ax2)= plt.subplots(nrows=2,ncols=1) # first wecode  fig lev ax
fig.suptitle('Iris_dataset')

ax1.hist(data.SepalLengthCm,color='g')
ax1.set_title('SepalLengthCm') # for giving titel of one graph
ax1.set_xlabel('SepalLengthCm')
ax1.set_ylabel('Counts')

ax2.hist(data.PetalLengthCm,color='k')
ax2.set_title('PetalLengthCm') # for giving titel of one graph
ax2.set_xlabel('PetalLengthCm')
ax2.set_ylabel('Counts')

plt.tight_layout() # -- remove overlapping of graph or count label
plt.show()

# %%
data.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
fig,((ax1,ax2),(ax3,ax4))= plt.subplots(nrows=2,ncols=2)

# %% [markdown]
# # 4plots

# %%
# here we are accessing figure  axex level object
fig,((ax1,ax2),(ax3,ax4))= plt.subplots(nrows=2,ncols=2) # first wecode  fig lev ax
fig.suptitle('Iris_dataset')

ax1.hist(data.SepalLengthCm,color='g')
ax1.set_title('SepalLengthCm') # for giving titel of one graph
ax1.set_xlabel('SepalLengthCm')
ax1.set_ylabel('Counts')

ax2.hist(data.PetalLengthCm,color='k')
ax2.set_title('PetalLengthCm') # for giving titel of one graph
ax2.set_xlabel('PetalLengthCm')
ax2.set_ylabel('Counts')

ax3.hist(data.SepalWidthCm,color='r')
ax3.set_title('SepalWidthCm') # for giving titel of one graph
ax3.set_xlabel('SepalWidthCm')
ax3.set_ylabel('Counts')

ax4.hist(data.PetalWidthCm,color='y')
ax4.set_title('PetalWidthCm') # for giving titel of one graph
ax4.set_xlabel('PetalWidthCm')
ax4.set_ylabel('Counts')

plt.tight_layout() # -- remove overlapping of graph or count label
plt.show()

# %% [markdown]
# # share x and share y

# %%
# here we are accessing figure  axex level object
fig,((ax1,ax2),(ax3,ax4))= plt.subplots(nrows=2,ncols=2,sharex=True,sharey=True) # first wecode  fig lev ax
fig.suptitle('Iris_dataset')

ax1.hist(data.SepalLengthCm,color='g')
ax1.set_title('SepalLengthCm') # for giving titel of one graph
ax1.set_xlabel('SepalLengthCm')
ax1.set_ylabel('Counts')

ax2.hist(data.PetalLengthCm,color='k')
ax2.set_title('PetalLengthCm') # for giving titel of one graph
ax2.set_xlabel('PetalLengthCm')
ax2.set_ylabel('Counts')

ax3.hist(data.SepalWidthCm,color='r')
ax3.set_title('SepalWidthCm') # for giving titel of one graph
ax3.set_xlabel('SepalWidthCm')
ax3.set_ylabel('Counts')

ax4.hist(data.PetalWidthCm,color='y')
ax4.set_title('PetalWidthCm') # for giving titel of one graph
ax4.set_xlabel('PetalWidthCm')
ax4.set_ylabel('Counts')

plt.tight_layout() # -- remove overlapping of graph or count label
plt.show()

# %% [markdown]
# # change fig size

# %%
# here we are accessing figure  axex level object

fig,((ax1,ax2),(ax3,ax4))= plt.subplots(nrows=2,ncols=2,sharex=True,sharey=True,figsize=(10,6))
fig.set_edgecolor('k')
fig.set_linewidth(6) # chane fig size
fig.set_facecolor('lightgreen')
fig.suptitle('Iris_dataset')

ax1.hist(data.SepalLengthCm,color='g')
ax1.set_title('SepalLengthCm') # for giving titel of one graph
ax1.set_xlabel('SepalLengthCm')
ax1.set_ylabel('Counts')

ax2.hist(data.PetalLengthCm,color='k')
ax2.set_title('PetalLengthCm') # for giving titel of one graph
ax2.set_xlabel('PetalLengthCm')
ax2.set_ylabel('Counts')

ax3.hist(data.SepalWidthCm,color='r')
ax3.set_title('SepalWidthCm') # for giving titel of one graph
ax3.set_xlabel('SepalWidthCm')
ax3.set_ylabel('Counts')

ax4.hist(data.PetalWidthCm,color='y')
ax4.set_title('PetalWidthCm') # for giving titel of one graph
ax4.set_xlabel('PetalWidthCm')
ax4.set_ylabel('Counts')

plt.tight_layout() # -- remove overlapping of graph or count label
plt.show()
